# %%
# !pip install mysql-connector-python

# %%
# creating a show all database query with try-except
import mysql.connector as connection
try:
    mydb = connection.connect(host="127.0.0.1",user="root", passwd="krds1998",use_pure=True)# check if the connection is established
    query = "SHOW DATABASES"
    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    out = cursor.fetchall()
    print(out)
except Exception as e:
    mydb.close()
    print(e)
# Out:
# [('information_schema',), ('mysql',), ('performance_schema',), ('sakila',), ('sales',), ('student2020',), ('sys',), ('world',)]

# %%
query = "Create Database Student2020;"
cursor.execute(query)

# %%
# Basic new table
try:
    mydb = connection.connect(host="127.0.0.1",database = 'student2020',user="root", passwd="krds1998",use_pure=True)# check if the connection is established
    query = "CREATE TABLE test(Studentid INT(10) AUTO_INCREMENT PRIMARY KEY,FirstName VARCHAR(60))"
    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    out = cursor.fetchall()
    print(out)
except Exception as e:
    print(e)
# Out:
# 1050 (42S01): Table 'test' already exists

# %%
cursor.execute("insert into test values(452222222,'ssdcsudhdfgd')")
cursor.execute("insert into test values(4541,'suadfsdhdfgd')")
cursor.execute("insert into test values(4542,'susdfdhdryjnfgfgd')")
cursor.execute("insert into test values(45422,'suxcdhdfgnhqgd')")
cursor.execute("insert into test values(454232,'sfudhdfgdsfd')")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-17-81bce6ff5c09> in <module>
# ----> 1 cursor.execute("insert into test values(452222222,'ssdcsudhdfgd')")
#       2 cursor.execute("insert into test values(4541,'suadfsdhdfgd')")
#       3 cursor.execute("insert into test values(4542,'susdfdhdryjnfgfgd')")
#       4 cursor.execute("insert into test values(45422,'suxcdhdfgnhqgd')")
#       5 cursor.execute("insert into test values(454232,'sfudhdfgdsfd')")
#
# C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     567
#     568         try:
# --> 569             self._handle_result(self._connection.cmd_query(stmt))
#     570         except errors.InterfaceError:
#     571             if self._connection._have_next_result:  # pylint: disable=W0212
#
# ...

# %%
cursor.execute("select * from test")
out = cursor.fetchall()
print(out)
# Out:
# [(4541, 'suadfsdhdfgd'), (4545, 'ssdcsudhdfgd'), (452222222, 'ssdcsudhdfgd')]

# %%
mydb.commit()

# %%
# creating a csv file from a table in mysql

import mysql.connector as connection
import pandas as pandas

try:

    mydb = connection.connect(host="localhost", database='sales', user="root", passwd="krds1998", use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())
    query = "Select * from sales.transactions;"
    result_dataFrame = pandas.read_sql(query,mydb)
    print(result_dataFrame)
#     cursor.execute(query)
#     out = cursor.fetchall()
#     print(out)
#     mydb.close()  # close the connection

except Exception as e:
    #mydb.close()
    print(str(e))

# %%
import pandas as pd

df = pd.read_csv('glass.csv',delimiter=',',dtype = str)

df= df.drop(df.columns[0],axis=1)
df.head()
# Out:
#   product_code customer_code market_code  order_date sales_qty sales_amount  \
# 0      Prod279        Cus020     Mark011  2017-10-11         1        102.0
# 1      Prod279        Cus020     Mark011  2017-10-18         1        102.0
# 2      Prod279        Cus020     Mark011  2017-10-19         1        102.0
# 3      Prod279        Cus020     Mark011  2017-11-08         1        102.0
# 4      Prod279        Cus020     Mark011  2018-03-09         1        102.0
#
#   currency profit_margin_percentage profit_margin cost_price
# 0      INR                     0.39         39.78      62.22
# 1      INR                    -0.12        -12.24     114.24
# 2      INR                     0.29         29.58      72.42
# 3      INR                     0.36         36.72      65.28
# 4      INR                    -0.35         -35.7      137.7

# %%
import mysql.connector as mysql
from mysql.connector import Error
try:
    conn = mysql.connect(host='127.0.0.1',database='student2020' ,user='root', password='krds1998')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select * from cust limit 10")
        output = cursor.fetchall()
        print(output)
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# [('Prod279', 'Cus020', 'Mark011', datetime.date(2017, 10, 11), 1, 102, 'INR', 0.39, 39.78, 62.22), ('Prod279', 'Cus020', 'Mark011', datetime.date(2017, 10, 18), 1, 102, 'INR', -0.12, -12.24, 114.24), ('Prod279', 'Cus020', 'Mark011', datetime.date(2017, 10, 19), 1, 102, 'INR', 0.29, 29.58, 72.42), ('Prod279', 'Cus020', 'Mark011', datetime.date(2017, 11, 8), 1, 102, 'INR', 0.36, 36.72, 65.28), ('Prod279', 'Cus020', 'Mark011', datetime.date(2018, 3, 9), 1, 102, 'INR', -0.35, -35.7, 137.7), ('Prod279', 'Cus020', 'Mark011', datetime.date(2018, 3, 20), 1, 102, 'INR', 0.26, 26.52, 75.48), ('Prod279', 'Cus020', 'Mark011', datetime.date(2018, 3, 22), 1, 102, 'INR', -0.35, -35.7, 137.7), ('Prod279', 'Cus020', 'Mark011', datetime.date(2018, 3, 23), 1, 102, 'INR', -0.35, -35.7, 137.7), ('Prod279', 'Cus020', 'Mark011', datetime.date(2018, 3, 29), 1, 102, 'INR', 0.34, 34.68, 67.32), ('Prod279', 'Cus020', 'Mark011', datetime.date(2018, 4, 16), 1, 102, 'INR', -0.06, -6.12, 108.12)]

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = mysql.connect(host='127.0.0.1',database='student2020' ,user='root', password='krds1998')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS cust;')
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
        cursor.execute("CREATE TABLE cust(prodno VARCHAR(60),custno VARCHAR(60), markt VARCHAR(60),tdate Date, sales_qty  INT(10),sales_amount INT(10),curr VARCHAR(60),profit_margin_percentage FLOAT(20),profit_margin FLOAT(20),costp FLOAT(20))")
        print("Table is created....")
        #loop through the data frame
        for i,row in df.iterrows():
            #here %S means string values 
            sql = "INSERT INTO student2020.cust VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('student2020',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...
